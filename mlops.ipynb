# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('diabetes_unclean.csv')
df.head()
# Out:
#     ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
df=df.drop('ID',axis=1)

# %%
df=df.drop('No_Pation',axis=1)

# %%
df
# Out:
#      Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI CLASS
# 0         F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 1         M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1   0.6  23.0     N
# 2         F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 3         F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 4         M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0   0.4  21.0     N
# ...     ...   ...   ...   ...    ...   ...  ...  ...  ...   ...   ...   ...
# 1004      M  55.0   NaN  62.0    6.8   5.3  2.0  1.0  3.5   0.9  30.1    Y
# 1005      M  55.0   4.8  88.0    NaN   5.7  4.0  0.9  3.3   1.8  30.0    Y
# 1006      M  62.0   6.3  82.0    6.7   5.3  2.0  1.0  3.5   NaN  30.1    Y
# 1007      F  57.0   4.1  70.0    9.3   5.3  3.3  1.0  1.4   1.3  29.0    Y
# 1008      f  55.0   4.1  34.0   13.9   5.4  1.6  1.6  3.1   0.7  33.0    Y
#
# [1009 rows x 12 columns]

# %%
df["CLASS"].unique()
# Out:
# <ArrowStringArray>
# ['N', 'N ', 'P', 'Y', 'Y ']
# Length: 5, dtype: str

# %%
df['CLASS'] = df['CLASS'].replace('N ', 'N')
df['CLASS'] = df['CLASS'].replace('Y ', 'Y')
df['CLASS'].unique()
# Out:
# <ArrowStringArray>
# ['N', 'P', 'Y']
# Length: 3, dtype: str

# %%
df["Gender"].unique()
# Out:
# <ArrowStringArray>
# ['F', 'M', 'f']
# Length: 3, dtype: str

# %%
df["Gender"] = df["Gender"].replace({"f": "F"})

# %%
df["Gender"].unique()
# Out:
# <ArrowStringArray>
# ['F', 'M']
# Length: 2, dtype: str

# %%
# Separate target column
target = df['CLASS']
 
# Features only
X = df.drop('CLASS', axis=1)
 
# One-hot encoding
X = pd.get_dummies(X)
 
# Add target back
df_coded = pd.concat([X, target], axis=1)
 
df_coded.head()
# Out:
#     AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI  Gender_F  \
# 0  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5  24.0      True
# 1  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1   0.6  23.0     False
# 2  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5  24.0      True
# 3  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5  24.0      True
# 4  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0   0.4  21.0     False
#
#    Gender_M CLASS
# 0     False     N
# 1      True     N
# 2     False     N
# 3     False     N
# 4      True     N

# %%
df_coded.isna().sum()
# Out:
# AGE         1
# Urea        1
# Cr          2
# HbA1c       3
# Chol        2
# TG          2
# HDL         1
# LDL         2
# VLDL        1
# BMI         0
# Gender_F    0
# Gender_M    0
# CLASS       0
# dtype: int64

# %%
df_coded=df_coded.fillna(df_coded.mean(numeric_only=True))

# %%
df
# Out:
#      Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI CLASS
# 0         F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 1         M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1   0.6  23.0     N
# 2         F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 3         F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 4         M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0   0.4  21.0     N
# ...     ...   ...   ...   ...    ...   ...  ...  ...  ...   ...   ...   ...
# 1004      M  55.0   NaN  62.0    6.8   5.3  2.0  1.0  3.5   0.9  30.1     Y
# 1005      M  55.0   4.8  88.0    NaN   5.7  4.0  0.9  3.3   1.8  30.0     Y
# 1006      M  62.0   6.3  82.0    6.7   5.3  2.0  1.0  3.5   NaN  30.1     Y
# 1007      F  57.0   4.1  70.0    9.3   5.3  3.3  1.0  1.4   1.3  29.0     Y
# 1008      F  55.0   4.1  34.0   13.9   5.4  1.6  1.6  3.1   0.7  33.0     Y
#
# [1009 rows x 12 columns]

# %%
df_coded.isna().sum()
# Out:
# AGE         0
# Urea        0
# Cr          0
# HbA1c       0
# Chol        0
# TG          0
# HDL         0
# LDL         0
# VLDL        0
# BMI         0
# Gender_F    0
# Gender_M    0
# CLASS       0
# dtype: int64

# %%
# 1) Bar chart showing the distribution of male and female patients
df['Gender'].value_counts().plot(kind='bar')
 
plt.title("Distribution of Male and Female Patients")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
df["AGE"].plot(kind='hist', bins=20)
plt.title("Distribution of Age")
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
df["BMI"].plot(kind='hist', bins=20)
plt.title("Distribution of BMI")
plt.xlabel("BMI")
# Out:
# Text(0.5, 0, 'BMI')

# %%
# 4) Scatter plot: BMI vs HbA1c (color-coded by diabetes class)
sns.scatterplot(x='BMI', y='HbA1c', hue='CLASS', data=df)
 
plt.title("BMI vs HbA1c")
plt.xlabel("BMI")
plt.ylabel("HbA1c")
plt.show()

# %%
# 4) Scatter plot: BMI vs HbA1c (color-coded by diabetes class)
sns.scatterplot(x='AGE', y='HbA1c', hue='CLASS', data=df)
 
plt.title("AGE vs HbA1c")
plt.xlabel("AGE")
plt.ylabel("HbA1c")
plt.show()

# %%
# 6) Box plot comparing BMI of diabetic vs non-diabetic patients
sns.boxplot(x='CLASS', y='BMI', data=df)
 
plt.title("BMI of Diabetic vs Non-Diabetic Patients")
plt.xlabel("Diabetes Class")
plt.ylabel("BMI")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x=df_coded.drop('CLASS', axis=1)
y=df_coded['CLASS']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate_model(y_test, y_pred):
    return {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, average='weighted'),
        "Recall": recall_score(y_test, y_pred, average='weighted'),
        "F1 Score": f1_score(y_test, y_pred, average='weighted')
    }

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression(max_iter=1000)
log_model.fit(x_train, y_train)
# Out:
# c:\Users\dell\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
y_pred_log = log_model.predict(x_test)

# %%
log_results = evaluate_model(y_test, y_pred_log)
log_results
# Out:
# {'Accuracy': 0.9405940594059405,
#  'Precision': 0.9392426311596677,
#  'Recall': 0.9405940594059405,
#  'F1 Score': 0.9390450792930296}

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC()
svm_model.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred_svm = svm_model.predict(x_test)

# %%
svm_results = evaluate_model(y_test, y_pred_svm)
svm_results
# Out:
# c:\Users\dell\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# {'Accuracy': 0.8663366336633663,
#  'Precision': 0.7505391628271737,
#  'Recall': 0.8663366336633663,
#  'F1 Score': 0.8042913044620111}

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier()
dt_model.fit(x_train, y_train)

y_pred_dt = dt_model.predict(x_test)

dt_results = evaluate_model(y_test, y_pred_dt)
dt_results
# Out:
# {'Accuracy': 0.9801980198019802,
#  'Precision': 0.9806577086280057,
#  'Recall': 0.9801980198019802,
#  'F1 Score': 0.9802073077851875}

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier()
rf_model.fit(x_train, y_train)

y_pred_rf = rf_model.predict(x_test)

rf_results = evaluate_model(y_test, y_pred_rf)
rf_results
# Out:
# {'Accuracy': 0.9851485148514851,
#  'Precision': 0.9849572457245723,
#  'Recall': 0.9851485148514851,
#  'F1 Score': 0.9849885551406923}

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(x_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knn_model.predict(x_test_scaled)

# %%
knn_results = evaluate_model(y_test, y_pred_knn)
knn_results
# Out:
# {'Accuracy': 0.9405940594059405,
#  'Precision': 0.9416338185542692,
#  'Recall': 0.9405940594059405,
#  'F1 Score': 0.9410624876707703}

# %%
import pandas as pd

results = pd.DataFrame([
    log_results,
    svm_results,
    dt_results,
    rf_results,
    knn_results
], index=[
    "Logistic Regression",
    "SVM",
    "Decision Tree",
    "Random Forest",
    "KNN"
])

results
# Out:
#                      Accuracy  Precision    Recall  F1 Score
# Logistic Regression  0.940594   0.939243  0.940594  0.939045
# SVM                  0.866337   0.750539  0.866337  0.804291
# Decision Tree        0.980198   0.980658  0.980198  0.980207
# Random Forest        0.985149   0.984957  0.985149  0.984989
# KNN                  0.940594   0.941634  0.940594  0.941062

# %%
best_model = dt_model

# %%
import joblib

# %%
joblib.dump(best_model, 'diabetes_model.pkl')
# Out:
# ['diabetes_model.pkl']

# %%
training_columns = x_train.columns

# %%
joblib.dump(training_columns, 'training_columns.pkl')
# Out:
# ['training_columns.pkl']
